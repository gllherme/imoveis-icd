# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score
from pandas.plotting import scatter_matrix

pd.options.display.max_columns = 99
pd.options.display.max_rows = 99

# %%
dataZAP = pd.read_csv('./data/dataZAP.csv', encoding='utf-8', sep=';', dtype=str ,low_memory=False)
new_data = pd.read_csv('./data/new_scraped_dataZAP.csv', encoding='utf-8', sep=';', dtype=str ,low_memory=False)

data = pd.concat([dataZAP, new_data])

# %% [markdown]
# # Tratamento dos dados

# %%
# Informações irrelevantes
data = data.drop(['account.licenseNumber', 'account.name', 'listing.acceptExchange',
                  'listing.address.zipCode', 'listing.advertiserId', 'listing.createdAt', 'listing.updatedAt',
                  'listing.externalId', 'listing.id','listing.isInactive', 'listing.legacyId', 'listing.link', 
                  'listing.portal', 'listing.preview', 'type', 'listing.address.confidence',  'listing.address.level', 'listing.businessTypeContext',
                  'listing.totalAreas', 'listing.unitTypes', 'listing.pricingInfo.rentalTotalPrice', 'listing.address.point.source', 'listing.address.precision', 'listing.address.streetNumber',
                  'listing.pricingInfo.businessType', 'listing.listingType', 'listing.pricingInfo.businessLabel',
                  'listing.propertyType', 'listing.title', 'listing.subtitle', 'listing.displayAddressType',
                  'listing.address.country', 'listing.pricingInfo.isRent', 'listing.publicationType',
                  'listing.pricingInfo.salePrice', 'listing.floors', 'listing.unitsOnTheFloor', 'listing.unitFloor', 'listing.unitSubTypes',
                  'listing.address.street', 'listing.address.zone', 'listing.pricingInfo.price', 'listing.address.point.lat',
                  'listing.address.point.lon', 'listing.amenities'], axis=1)

# Amenities
data = data.drop(['listing.backyard', 'listing.barbgrill' ,	'listing.bathtub', 'listing.fireplace', 'listing.furnished',
                  'listing.garden', 'listing.guestpark', 'listing.gym', 'listing.hottub', 'listing.mountainview', 
                  'listing.partyhall', 'listing.playground', 'listing.pool', 'listing.sauna',
                  'listing.soundproofing', 'listing.sportcourt', 'listing.tenniscourt'], axis=1)

# %%
# Removendo imoveis alugados por temporada
to_remove = data.query('`listing.pricingInfo.period` == "dia" or `listing.pricingInfo.period` == "semana" or `listing.pricingInfo.period` == "ano"')
data = data.drop(to_remove.index)

data = data.drop('listing.pricingInfo.period', axis=1)

# %%
# Removendo linhas duplicadas
data = data.drop_duplicates()

# %%
# Reseta o index da tabela
data.reset_index(inplace=True)
data = data.drop('index', axis=1)

# %%
# Remove imoveis comerciais
data = data.drop(data[data['listing.usageTypes'] == 'COMMERCIAL'].index)
data = data.drop(data[data['listing.usageTypes'] == 'RESIDENTIAL|COMMERCIAL'].index)
data.drop(['listing.usageTypes'], axis=1)
# Out:
#           imvl_type listing.address.city listing.address.neighborhood  \
# 0      apartamentos            São Paulo               Parada Inglesa
# 1      apartamentos        Florianópolis                   Agronômica
# 2      apartamentos       Rio de Janeiro     Recreio Dos Bandeirantes
# 3      apartamentos             Campinas                       Cambuí
# 4      apartamentos            São Paulo                     Ipiranga
# ...             ...                  ...                          ...
# 75888  apartamentos               Canoas                       Centro
# 75889  apartamentos       Belo Horizonte                     Planalto
# 75890  apartamentos              Goiânia            Setor Faiçalville
# 75891  apartamentos            São Paulo              Vila Aricanduva
# 75892  apartamentos            São Paulo                        Saúde
#
#       listing.address.state listing.bathrooms listing.bedrooms  \
# 0                 São Paulo                 1                2
# 1            Santa Catarina                 3                3
# 2            Rio de Janeiro                 3                3
# 3                 São Paulo                 2                1
# 4                 São Paulo                 3                2
# ...                     ...               ...              ...
# 75888     Rio Grande do Sul                 1                2
# 75889          Minas Gerais                 1                2
# 75890                 Goiás                 1                2
# 75891             São Paulo                 1                2
# 75892             São Paulo                 2                2
#
#                                      listing.description  \
# 0      LINDO APARTAMENTO PARADA INGLESA<br><br>2 DORM...
# 1      EXCELENTE LOCALIZAÇÃO - TRANQUILIDADE E COMODI...
# 2      Cód: TIAP32493. Para quem quer morar próximo d...
# 3      Apartamento mobiliado para alugar no Cambuí.<b...
# 4      Alugue rápido, sem fiador e com segurança! Age...
# ...                                                  ...
# 75888  Apartamento para Aluguel - Centro, 2 Quartos, ...
# 75889  Apartamento para Aluguel - Planalto, 2 Quartos...
# 75890  Apartamento para Aluguel - Setor Faicalville, ...
# 75891  Apartamento para Aluguel - Vila Aricanduva, 2 ...
# 75892  Apartamento para Aluguel - Saúde, 2 Quartos, 5...
#
#       listing.parkingSpaces listing.pricingInfo.isSale  \
# 0                    normal                      False
# 1                         1                      False
# 2                         2                      False
# 3                         1                      False
# 4                         2                      False
# ...                     ...                        ...
# 75888                     0                      False
# 75889                     1                      False
# 75890                     1                      False
# 75891                     0                      False
# 75892                     1                      False
#
#       listing.pricingInfo.monthlyCondoFee listing.pricingInfo.rentalPrice  \
# 0                                      50                           1.300
# 1                                   1.961                           3.600
# 2                                     835                           2.100
# 3                                 134.437                           3.000
# 4                                     536                           2.600
# ...                                   ...                             ...
# 75888                                 265                           1.100
# 75889                                 411                           1.600
# 75890                                 326                           1.300
# 75891                                  90                           1.350
# 75892                               1.146                           1.700
#
#       listing.pricingInfo.yearlyIptu listing.suites listing.usableAreas
# 0                                 50         normal                  45
# 1                                370              1                 140
# 2                                244              1                 100
# 3                                 90              0                  80
# 4                                 17              2                  69
# ...                              ...            ...                 ...
# 75888                             71              0                  69
# 75889                            100              0                  48
# 75890                             59              0                  45
# 75891                             94              0                  39
# 75892                             55              0                  57
#
# [75730 rows x 14 columns]

# %%
data.head(10)
# Out:
#       imvl_type   listing.address.city listing.address.neighborhood  \
# 0  apartamentos              São Paulo               Parada Inglesa
# 1  apartamentos          Florianópolis                   Agronômica
# 2  apartamentos         Rio de Janeiro     Recreio Dos Bandeirantes
# 3  apartamentos               Campinas                       Cambuí
# 4  apartamentos              São Paulo                     Ipiranga
# 5  apartamentos         Rio de Janeiro              Barra da Tijuca
# 6  apartamentos              São Paulo                     Brooklin
# 7  apartamentos              São Paulo                      Tatuapé
# 8  apartamentos  São José do Rio Preto              Jardim Panorama
# 9  apartamentos           Porto Alegre              Jardim Botânico
#
#   listing.address.state listing.bathrooms listing.bedrooms  \
# 0             São Paulo                 1                2
# 1        Santa Catarina                 3                3
# 2        Rio de Janeiro                 3                3
# 3             São Paulo                 2                1
# 4             São Paulo                 3                2
# 5        Rio de Janeiro                 1                2
# 6             São Paulo                 2                1
# 7             São Paulo                 2                2
# 8             São Paulo                 2                2
# 9     Rio Grande do Sul                 1                2
#
#                                  listing.description listing.parkingSpaces  \
# 0  LINDO APARTAMENTO PARADA INGLESA<br><br>2 DORM...                normal
# 1  EXCELENTE LOCALIZAÇÃO - TRANQUILIDADE E COMODI...                     1
# 2  Cód: TIAP32493. Para quem quer morar próximo d...                     2
# 3  Apartamento mobiliado para alugar no Cambuí.<b...                     1
# 4  Alugue rápido, sem fiador e com segurança! Age...                     2
# 5  O apartamento no bairro Barra da Tijuca tem 64...                     1
# 6  Alugue rápido, sem fiador e com segurança! Age...                     1
# 7  Amplo apartamento com piso laminado, cozinha e...                     1
# 8                                      Atualizado em                     1
# 9  Excelente apartamento com pintura e synteko no...                     0
#
#   listing.pricingInfo.isSale listing.pricingInfo.monthlyCondoFee  \
# 0                      False                                  50
# 1                      False                               1.961
# 2                      False                                 835
# 3                      False                             134.437
# 4                      False                                 536
# 5                      False                                 809
# 6                      False                                 880
# 7                      False                                 800
# 8                      False                                 450
# 9                      False                                 260
#
#   listing.pricingInfo.rentalPrice listing.pricingInfo.yearlyIptu  \
# 0                           1.300                             50
# 1                           3.600                            370
# 2                           2.100                            244
# 3                           3.000                             90
# 4                           2.600                             17
# 5                           2.500                            236
# 6                           4.900                            109
# 7                           1.900                            132
# 8                           1.400                             73
# 9                           1.000                             30
#
#   listing.suites listing.usableAreas listing.usageTypes
# 0         normal                  45        RESIDENTIAL
# 1              1                 140        RESIDENTIAL
# 2              1                 100        RESIDENTIAL
# 3              0                  80        RESIDENTIAL
# 4              2                  69        RESIDENTIAL
# 5              1                  64        RESIDENTIAL
# 6              1                  67        RESIDENTIAL
# 7              1                  73        RESIDENTIAL
# 8              2                  70        RESIDENTIAL
# 9              0                  52        RESIDENTIAL

# %%
# Remove o "." da string para preservar o valor correto na conversão para float e converte para valores numéricos

data['listing.pricingInfo.monthlyCondoFee'] = data['listing.pricingInfo.monthlyCondoFee'].str.replace('.', '')
data['listing.pricingInfo.rentalPrice'] = data['listing.pricingInfo.rentalPrice'].str.replace('.', '')
data['listing.usableAreas'] = data['listing.usableAreas'].str.replace('.', '')
data['listing.pricingInfo.yearlyIptu'] = data['listing.pricingInfo.yearlyIptu'].str.replace('.', '')

# errors='coerce' - Os valores 'normal' são convertidos em 'NaN'
data['listing.usableAreas'] = pd.to_numeric(data['listing.usableAreas'], errors='coerce')

data['listing.pricingInfo.monthlyCondoFee'] = pd.to_numeric(data['listing.pricingInfo.monthlyCondoFee'], errors='coerce')
data['listing.pricingInfo.rentalPrice'] = pd.to_numeric(data['listing.pricingInfo.rentalPrice'], errors='coerce')
data['listing.pricingInfo.yearlyIptu'] = pd.to_numeric(data['listing.pricingInfo.yearlyIptu'], errors='coerce')

# data['listing.address.point.lat'] = pd.to_numeric(data['listing.address.point.lat'],errors='coerce')
# data['listing.address.point.lon'] = pd.to_numeric(data['listing.address.point.lon'],errors='coerce')

data['listing.suites'] = pd.to_numeric(data['listing.suites'], errors = 'coerce')
data['listing.bedrooms'] = pd.to_numeric(data['listing.bedrooms'], errors='coerce')
data['listing.bathrooms'] = pd.to_numeric(data['listing.bathrooms'], errors='coerce')
data['listing.parkingSpaces'] = pd.to_numeric(data['listing.parkingSpaces'], errors = 'coerce')

# Booleano
data['listing.pricingInfo.isSale'] = data['listing.pricingInfo.isSale'].astype(bool)
# Out:
# /tmp/ipykernel_30136/3569676157.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['listing.pricingInfo.monthlyCondoFee'] = data['listing.pricingInfo.monthlyCondoFee'].str.replace('.', '')
# /tmp/ipykernel_30136/3569676157.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['listing.pricingInfo.rentalPrice'] = data['listing.pricingInfo.rentalPrice'].str.replace('.', '')
# /tmp/ipykernel_30136/3569676157.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['listing.usableAreas'] = data['listing.usableAreas'].str.replace('.', '')
# /tmp/ipykernel_30136/3569676157.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['listing.pricingInfo.yearlyIptu'] = data['listing.pricingInfo.yearlyIptu'].str.replace('.', '')

# %%
data.head(10)
# Out:
#       imvl_type   listing.address.city listing.address.neighborhood  \
# 0  apartamentos              São Paulo               Parada Inglesa
# 1  apartamentos          Florianópolis                   Agronômica
# 2  apartamentos         Rio de Janeiro     Recreio Dos Bandeirantes
# 3  apartamentos               Campinas                       Cambuí
# 4  apartamentos              São Paulo                     Ipiranga
# 5  apartamentos         Rio de Janeiro              Barra da Tijuca
# 6  apartamentos              São Paulo                     Brooklin
# 7  apartamentos              São Paulo                      Tatuapé
# 8  apartamentos  São José do Rio Preto              Jardim Panorama
# 9  apartamentos           Porto Alegre              Jardim Botânico
#
#   listing.address.state  listing.bathrooms  listing.bedrooms  \
# 0             São Paulo                1.0               2.0
# 1        Santa Catarina                3.0               3.0
# 2        Rio de Janeiro                3.0               3.0
# 3             São Paulo                2.0               1.0
# 4             São Paulo                3.0               2.0
# 5        Rio de Janeiro                1.0               2.0
# 6             São Paulo                2.0               1.0
# 7             São Paulo                2.0               2.0
# 8             São Paulo                2.0               2.0
# 9     Rio Grande do Sul                1.0               2.0
#
#                                  listing.description  listing.parkingSpaces  \
# 0  LINDO APARTAMENTO PARADA INGLESA<br><br>2 DORM...                    NaN
# 1  EXCELENTE LOCALIZAÇÃO - TRANQUILIDADE E COMODI...                    1.0
# 2  Cód: TIAP32493. Para quem quer morar próximo d...                    2.0
# 3  Apartamento mobiliado para alugar no Cambuí.<b...                    1.0
# 4  Alugue rápido, sem fiador e com segurança! Age...                    2.0
# 5  O apartamento no bairro Barra da Tijuca tem 64...                    1.0
# 6  Alugue rápido, sem fiador e com segurança! Age...                    1.0
# 7  Amplo apartamento com piso laminado, cozinha e...                    1.0
# 8                                      Atualizado em                    1.0
# 9  Excelente apartamento com pintura e synteko no...                    0.0
#
#    listing.pricingInfo.isSale  listing.pricingInfo.monthlyCondoFee  \
# 0                        True                                 50.0
# 1                        True                               1961.0
# 2                        True                                835.0
# 3                        True                             134437.0
# 4                        True                                536.0
# 5                        True                                809.0
# 6                        True                                880.0
# 7                        True                                800.0
# 8                        True                                450.0
# 9                        True                                260.0
#
#    listing.pricingInfo.rentalPrice  listing.pricingInfo.yearlyIptu  \
# 0                             1300                            50.0
# 1                             3600                           370.0
# 2                             2100                           244.0
# 3                             3000                            90.0
# 4                             2600                            17.0
# 5                             2500                           236.0
# 6                             4900                           109.0
# 7                             1900                           132.0
# 8                             1400                            73.0
# 9                             1000                            30.0
#
#    listing.suites  listing.usableAreas listing.usageTypes
# 0             NaN                 45.0        RESIDENTIAL
# 1             1.0                140.0        RESIDENTIAL
# 2             1.0                100.0        RESIDENTIAL
# 3             0.0                 80.0        RESIDENTIAL
# 4             2.0                 69.0        RESIDENTIAL
# 5             1.0                 64.0        RESIDENTIAL
# 6             1.0                 67.0        RESIDENTIAL
# 7             1.0                 73.0        RESIDENTIAL
# 8             2.0                 70.0        RESIDENTIAL
# 9             0.0                 52.0        RESIDENTIAL

# %%
# Cria uma coluna ALUGUEL na primeira posição para substituir a coluna listing.pricingInfo.rentalPrice
data.insert(0, 'ALUGUEL', data['listing.pricingInfo.rentalPrice'] )
data.drop('listing.pricingInfo.rentalPrice', axis=1, inplace=True)

data.insert(0, 'PADRAO', '')

# %% [markdown]
# ## Tratamento de outliers

# %% [markdown]
# ### Aluguel

# %%
fig = plt.figure(figsize=(18, 12))
plt.boxplot([data.query('ALUGUEL < 100000 and imvl_type == "quitinetes"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "flat"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "studio"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "casas-de-vila"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "casas"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "casas-de-condominio"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "apartamentos"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "cobertura"')['ALUGUEL']],
            labels=['quitinetes', 'flats', 'studios', 'casas-de-vila', 'casas', 
                    'casas-de-condominio', 'apartamentos', 'coberturas'])
plt.grid()

# %%
data['ALUGUEL'].quantile(0.9)
# Out:
# 14000.0

# %%
data.drop(data.query('ALUGUEL > 14000').index, inplace=True)

# %%
data.describe()
# Out:
#             ALUGUEL  listing.bathrooms  listing.bedrooms  \
# count  68386.000000       68383.000000      68349.000000
# mean    3432.906911           2.035257          2.110989
# std     3048.540673           1.514749          1.198603
# min      150.000000           0.000000          0.000000
# 25%     1200.000000           1.000000          1.000000
# 50%     2392.000000           1.000000          2.000000
# 75%     4500.000000           3.000000          3.000000
# max    14000.000000          20.000000         30.000000
#
#        listing.parkingSpaces  listing.pricingInfo.monthlyCondoFee  \
# count           63268.000000                         4.644600e+04
# mean                1.647974                         1.049655e+03
# std                 2.511301                         1.153283e+04
# min                 0.000000                         1.000000e+00
# 25%                 1.000000                         3.300000e+02
# 50%                 1.000000                         6.000000e+02
# 75%                 2.000000                         1.108000e+03
# max               403.000000                         2.058000e+06
#
#        listing.pricingInfo.yearlyIptu  listing.suites  listing.usableAreas
# count                    4.679200e+04    57562.000000         6.838500e+04
# mean                     6.906485e+02        1.061759         1.589165e+03
# std                      2.150439e+04        1.184757         1.209171e+05
# min                      1.000000e+00        0.000000         0.000000e+00
# 25%                      6.800000e+01        0.000000         3.800000e+01
# 50%                      1.700000e+02        1.000000         7.000000e+01
# 75%                      3.830000e+02        1.000000         1.650000e+02
# max                      2.900000e+06       46.000000         9.999999e+06

# %% [markdown]
# Resultado

# %%
fig = plt.figure(figsize=(18, 12))
plt.boxplot([data.query('ALUGUEL < 100000 and imvl_type == "quitinetes"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "flat"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "studio"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "casas-de-vila"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "casas"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "casas-de-condominio"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "apartamentos"')['ALUGUEL'],
            data.query('ALUGUEL < 100000 and imvl_type == "cobertura"')['ALUGUEL']],
            labels=['quitinetes', 'flats', 'studios', 'casas-de-vila', 'casas', 
                    'casas-de-condominio', 'apartamentos', 'coberturas'])
plt.grid()

# %%
# verificando os outliers dos quitinetes é possivel observar que não são erros nos valores dos anuncios no ZAP

data.query(' imvl_type == "quitinetes" and ALUGUEL > 6000')[['ALUGUEL','listing.pricingInfo.monthlyCondoFee','listing.address.city','listing.address.neighborhood','listing.bathrooms','listing.bedrooms','listing.parkingSpaces','listing.usableAreas', 'listing.description']].values
# Out:
# array([[6975, 790.0, 'São Paulo', 'Itaim Bibi', 1.0, 1.0, 1.0, 54.0,
#         'Mobiliado e equipado, 1suíte, living, cozinha, ar-condicionado, serviço de lavanderia e 1 vaga de garagem. Localizado à 800 metros do Shopping Iguatemi, Parque do Povo e à 300 metros da Avenida Brigadeiro Faria Lima. -'],
#        [8500, 1500.0, 'São Paulo', 'Jardim Paulista', 2.0, 2.0, 2.0,
#         88.0,
#         'Studio Cobertura Duplex totalmente mobiliado, Com duas suítes, sacada ampla com fechamento em vidro, uma vaga de garagem, piso em porcelanato, moveis e eletrodomésticos novos, tudo planejado para atender você. Localizado à poucos metros do Parque do Ibirapuera. Áreas comuns totalmente mobiliadas e decoradas, contando com serviço de arrumação e lavanderia "pay per use", além de estacionamento com manobrista. Amplo fitness, piscina com pequena raia, áreas ajardinadas com paisagismo de Gil Fialho, lounge para festas e espaço gourmet completo, home office e lavanderia coletiva (HVB). O charme e a exclusividade ficam por conta dos apenas oito andares e da elegância da fachada, concebida com materiais nobres. Vem conhecer e se encantar !! -'],
#        [6100, 1100.0, 'São Paulo', 'Jardim Paulista', 1.0, 1.0, 1.0,
#         73.0,
#         'Studio, totalmente mobiliado com móveis e eletrodomésticos de primeira linha, inclusive com roupa de cama, mesa e banho. . O diferencial deste imóvel, além de toda a classe e conforto, fica por conta do "garden" privativo. Você pode desfrutar de um espaço exclusivo ao ar livre como se estivesse numa casa. Não há nada igual. (HVB) Destaco a área de lazer do empreendimento com amplo fitness, piscina com raia (13m), sauna com ducha, lounge para festas, espaço gourmet com churrasqueira, home office, lavanderia e vestiário para diaristas. Todos estes espaços, mobiliados e decorados com requinte e bom gosto. Alinhados com o conceito de vida moderno, os apartamentos possuem serviço de arrumação e lavanderia "pay per use", além de estacionamento com manobrista. -'],
#        [6100, 1100.0, 'São Paulo', 'Jardim Paulista', 1.0, 1.0, 1.0,
#         72.0,
')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "cobertura"')['listing.pricingInfo.monthlyCondoFee']],
             labels=['quitinetes', 'flat', 'studio', 'casas',
                     'casas-de-vila', 'casas-de-condominio',
                     'apartamentos', 'cobertura'])
plt.title('Taxa de condomínio')
plt.grid()
plt.show()

# %%
data['listing.pricingInfo.monthlyCondoFee'].quantile(0.99)
# Out:
# 4500.0

# %%
data.drop(data.query('`listing.pricingInfo.monthlyCondoFee` > 5000').index, inplace=True)

# %% [markdown]
# Resultado

# %%
fig = plt.figure(figsize=(18, 12))
plt.boxplot( [data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "quitinetes"')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "flat"')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "studio"')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "casas"')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "casas-de-vila"')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "apartamentos"')['listing.pricingInfo.monthlyCondoFee'], 
              data[data['listing.pricingInfo.monthlyCondoFee'].notnull()].query('imvl_type == "cobertura"')['listing.pricingInfo.monthlyCondoFee']],
             labels=['quitinetes', 'flat', 'studio', 'casas',
                     'casas-de-vila', 'casas-de-condominio',
                     'apartamentos', 'cobertura'])
plt.title('Taxa de condomínio')
plt.grid()
plt.show()

# %%
# verificando os outliers é possivel observar que não são erros nos valores dos anuncios no ZAP

data.query('`listing.pricingInfo.monthlyCondoFee` > 3000')[['ALUGUEL','listing.pricingInfo.monthlyCondoFee','listing.address.city','listing.address.neighborhood','listing.bathrooms','listing.bedrooms','listing.parkingSpaces','listing.usableAreas', 'listing.description']].values
# Out:
# array([[12500, 3800.0, 'Rio de Janeiro', ..., 2.0, 260.0,
#         '260m2 – apartamento de esquina com vista lateral mar e Jardim de Alah - prédio com grade, câmeras e portaria 24hs, 1 por andar – 2 vagas. Planta circular, claro e ventilado. Pintado e sintecado. Amplo salão com vista, lavabo, louceiro. 4 quartos sendo 1 suíte, todos c/ armários e Split. Banheiro social. Espaçosa cozinha, área de serviço e 2 dependências completas. Mobiliado ou não. Split em todos os cômodos.'],
#        [3400, 3862.0, 'São Paulo', ..., 4.0, 373.0,
#         'Living amplo ambientes integrados: varanda, sala de lareira, sala de jantar e sala de almoço cozinha planejada com despensa. 4 dormitórios com armários e terraços: sendo 3 suítes e mais dormitório com banheiro. A suíte master com hidro, terraço, closet, repletos de armários. 4 vagas demarcadas paralelas e depósito. Edifico possui lazer Completo com muito verde ao redor. Rua Tranquila sem saída e com cancela. -'],
#        [5300, 3450.0, 'Rio de Janeiro', ..., 2.0, 126.0,
#         'Apartamento no n Condomínio Ocean Front ,totalmente mobiliado e decorado . Andar alto, vista deslumbrante para o mar e montanha composto de varanda ampla, sala 2 ambientes , lavabo, 3 quartos sendo 1 suíte, copa-cozinha planejada, área de serviço e dependência completa. Condomínio clube com total infraestrutura de lazer, restaurante, e localização privilegiada. Segurança 24 horas em guarita e interna. Acordar com o som das ondas, é isso que o Ocean Front oferece aos seus moradores. Com localização privilegiada na Praia da Barra da Tijuca, o condomínio possui 4 edifícios , Além da excelente localização, condomínio oferece serviço de concierge, faxineira e arrumadeira, central de reparos e manutenção.Área de lazer completa. São 4 piscinas, sendo uma (1) descoberta, sauna, SPA, quadras de tênis, squash, poliesportiva, brinquedoteca, home theater, salão de festas e restaurante. Segurança total 24 horas.O Ocean Front é um condomínio de apartamento de luxo'],
#        ...,
#        [9000, 4900.0, 'Mogi das Cruzes', ..., 4.0, 255.0,
#         'Apartamento para Aluguel - Vila Oliveira, 3 Quartos, 255 m2. Sobre o imóvel: <br><br>Valores:<br>- Aluguel: 9000<br>- Condomínio: 4900<br>- IPTU: 833<br><br>Que tal agendar uma visita?<br>Entre em contato pelo formulário. Você receberá uma mensagem por e-mail e WhatsApp com os próximos passos.<br><br>Seu imóvel sem burocracia<br>O QuintoAndar revolucionou o jeito de alugar e comprar imóveis: rápido, fácil, online, sem fiador e o melhor, sem burocracia. Conheça esse e outros imóveis no site do QuintoAndar. CRECI-SP J24.344'],
#        [6177, 3640.0, 'São Paulo', ..., 2.0, 142.0,
#         'Apartamento para Aluguel - Jardim Paulista, 3 Quartos, 142 m2. Sobre o imóvel: Amplo apartamento nos Jardins, excelente localização, rua arborizada, próximo à Av Paulista, metrôs Oscar Freire, Consolação e Paulista. Situado no 7° andar, um apto por andar, claro e arejado, reforma recente incluindo elétrica e hidráulica. Sala para até 3 ambientes, 3 quartos com armários embutidos, sendo uma suíte com Jacuzzi e ar condicionado tipo split. Rouparia. Cozinha completa, equipada com geladeira side-by-side, fogão 6 bocas, micro-ondas, coifa, lava-louças e armários planejados; área de serviço com lavadora, quarto de empregada e wc. Duas vagas de garagem independentes. Câmeras e portaria 24 horas. Salão de Festas.<br><br>Valores:<br>- Aluguel: 6177<br>- Condomínio: 3640<br>- IPTU: 956<br><br>Que tal agendar uma visita?<br>Entre em contato pelo formulário. Você receberá uma mensagem por e-mail e WhatsApp com os próximos passos.<br><br>Seu imóvel sem burocracia<br>O QuintoAndar revolucionou o jeito de alugar e comprar'],
#        [12000, 4256.0, 'São Paulo', ..., 5.0, 304.0,
#         '<br><br><br>Apartamento no bairro Morumbi com 304m² área privativa/útil, 2 dormitório(s), 2 suíte(s), 5 vaga(s), 5 banheiro(s), terraço, dep. de empregados.<br>']],
#       dtype=object)

# %% [markdown]
# ### Quartos

# %%
fig = plt.figure(figsize=(18, 12))
plt.boxplot( [data.query('imvl_type == "quitinetes"')['listing.bedrooms'], 
              data.query('imvl_type == "flat"')['listing.bedrooms'], 
              data.query('imvl_type == "studio"')['listing.bedrooms'], 
              data.query('imvl_type == "casas"')['listing.bedrooms'], 
              data.query('imvl_type == "casas-de-vila"')['listing.bedrooms'], 
              data.query('imvl_type == "casas-de-condominio"')['listing.bedrooms'], 
              data.query('imvl_type == "apartamentos"')['listing.bedrooms'], 
              data.query('imvl_type == "cobertura"')['listing.bedrooms'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas',
                        'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %%
data.query('imvl_type == "quitinetes" and `listing.bedrooms`>5')
# Out:
#       PADRAO  ALUGUEL   imvl_type listing.address.city  \
# 22730             970  quitinetes       Belo Horizonte
# 22758            1100  quitinetes            São Paulo
# 22777             680  quitinetes         Porto Alegre
#
#       listing.address.neighborhood listing.address.state  listing.bathrooms  \
# 22730                  Mangabeiras          Minas Gerais                5.0
# 22758                      Butantã             São Paulo                0.0
# 22777                     Partenon     Rio Grande do Sul                3.0
#
#        listing.bedrooms                                listing.description  \
# 22730               9.0                                             normal
# 22758              14.0  ÓTIMAS SUÍTES NO BUTANTÃ-Jd.Bonfiglioli Dispon...
# 22777               9.0  "Muitooo" perto da PUC e UFRGS - Campus do Val...
#
#        listing.parkingSpaces  listing.pricingInfo.isSale  \
# 22730                    7.0                        True
# 22758                    3.0                        True
# 22777                    0.0                        True
#
#        listing.pricingInfo.monthlyCondoFee  listing.pricingInfo.yearlyIptu  \
# 22730                                  NaN                             NaN
# 22758                                  NaN                             NaN
# 22777                                  NaN                             NaN
#
#        listing.suites  listing.usableAreas listing.usageTypes
# 22730             5.0                 30.0        RESIDENTIAL
# 22758            14.0                 25.0        RESIDENTIAL
# 22777             1.0                 16.0        RESIDENTIAL

# %%
# Remove quitinetes com mais que 5 quartos já que são erros nos dados

data.drop(data.query('imvl_type == "quitinetes" and `listing.bedrooms`>5').index, inplace=True)

# %% [markdown]
# ### Banheiros

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data.query('imvl_type == "quitinetes"')['listing.bathrooms'], 
              data.query('imvl_type == "flat"')['listing.bathrooms'], 
              data.query('imvl_type == "studio"')['listing.bathrooms'], 
              data.query('imvl_type == "casas"')['listing.bathrooms'], 
              data.query('imvl_type == "casas-de-vila"')['listing.bathrooms'], 
              data.query('imvl_type == "casas-de-condominio"')['listing.bathrooms'], 
              data.query('imvl_type == "apartamentos"')['listing.bathrooms'], 
              data.query('imvl_type == "cobertura"')['listing.bathrooms'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas',
                     'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %%
data.drop(data.query('imvl_type == "quitinetes" and `listing.bathrooms`>5').index, inplace=True)
data.drop(data.query('imvl_type == "flat" and `listing.bathrooms`>5').index, inplace=True)

# %% [markdown]
# ### Suites

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.suites'].notnull()].query('imvl_type == "quitinetes"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "flat"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "studio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-vila"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "apartamentos"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "cobertura"')['listing.suites'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()   
plt.show()

# %%
data.query('`listing.suites` > 10')
# Out:
#       PADRAO  ALUGUEL            imvl_type listing.address.city  \
# 5234             5500  casas-de-condominio       Rio de Janeiro
# 45459             350           quitinetes            Fortaleza
# 52717            2500        casas-de-vila         Campo Grande
# 53295            9900  casas-de-condominio              Goiânia
# 54746           12000  casas-de-condominio             Tremembé
#
#       listing.address.neighborhood listing.address.state  listing.bathrooms  \
# 5234      Recreio Dos Bandeirantes        Rio de Janeiro                6.0
# 45459                      Benfica                 Ceará                1.0
# 52717         Vila Manoel Taveira     Mato Grosso do Sul               11.0
# 53295              Jardim Florença                 Goiás                6.0
# 54746                       Guedes             São Paulo               18.0
#
#        listing.bedrooms                                listing.description  \
# 5234                4.0  CCO1155- Condomínio Nova Barra - Alugamos ótim...
# 45459               1.0  O kitnet/conjugado está localizado no bairro F...
# 52717              11.0  Aluguel facilitado sem fiador<br>A casa de vil...
# 53295               4.0  + Residência de esquina, localizado na Alameda...
# 54746              30.0  A casa de condomínio está localizado no bairro...
#
#        listing.parkingSpaces  listing.pricingInfo.isSale  \
# 5234                     2.0                        True
# 45459                    0.0                        True
# 52717                    1.0                        True
# 53295                    4.0                        True
# 54746                   24.0                        True
#
#        listing.pricingInfo.monthlyCondoFee  listing.pricingInfo.yearlyIptu  \
# 5234                                 850.0                           400.0
# 45459                                  NaN                            30.0
# 52717                                  NaN                             NaN
# 53295                                  NaN                             1.0
# 54746                                101.0                           380.0
#
#        listing.suites  listing.usableAreas listing.usageTypes
# 5234             46.0                280.0        RESIDENTIAL
# 45459            19.0                 22.0        RESIDENTIAL
# 52717            11.0                182.0        RESIDENTIAL
# 53295            31.0                339.0        RESIDENTIAL
# 54746            15.0               1058.0        RESIDENTIAL

# %%
data.query('`listing.suites` > 10').values
# Out:
# array([['', 5500, 'casas-de-condominio', 'Rio de Janeiro',
#         'Recreio Dos Bandeirantes', 'Rio de Janeiro', 6.0, 4.0,
#         'CCO1155- Condomínio Nova Barra - Alugamos ótima casa com 4 suítes, sala de estar, sala de jantar, lavabo, escritório, cozinha, dependência de empregada e área de serviço.Armários planejados em todos os ambientes.Infraestrutura: piscina e churrasqueira.Segurança 24 horas.',
#         2.0, True, 850.0, 400.0, 46.0, 280.0, 'RESIDENTIAL'],
#        ['', 350, 'quitinetes', 'Fortaleza', 'Benfica', 'Ceará', 1.0, 1.0,
#         'O kitnet/conjugado está localizado no bairro Farias Brito tem 22 metros quadrados com 1 quarto sendo 19 suites e 19 banheiros<br>Possui espaço jardinado.<br>Além disso segurança garantida 24 horas por dia.Encontra-se em um condomínio protegido por muros.<br><br>Rua: Princesa Isabel, N° 1749',
#         0.0, True, nan, 30.0, 19.0, 22.0, 'RESIDENTIAL'],
#        ['', 2500, 'casas-de-vila', 'Campo Grande',
#         'Vila Manoel Taveira ', 'Mato Grosso do Sul', 11.0, 11.0,
#         'Aluguel facilitado sem fiador<br>A casa de vila está localizado no bairro Vila Manoel Taveira tem 400 metros quadrados com 11 quartos sendo 11 suites e 11 banheirosFica em um condomínio fechado.',
#         1.0, True, nan, nan, 11.0, 182.0, 'RESIDENTIAL'],
#        ['', 9900, 'casas-de-condominio', 'Goiânia', 'Jardim Florença',
#         'Goiás', 6.0, 4.0,
#         '+ Residência de esquina, localizado na Alameda dos <br>+ Área do Terreno: 604mt2<br>+ Área Construída: 339mt2<br>+ Sala ampla<br>+ Cozinha rica em armários<br>+ 4 Quartos, sendo: 3 Suítes + 01 Suíte Master com Banheira de hidromassagem e sacada, todos com armários e entrada para ar-condicionado<br>+ lavabo<br>+ Piscina<br>+ Varanda<br>+ Área para Churrasqueira com pia e balcão<br>+ Garagem para 4 carros<br>+ Área de Serviço<br>+ DCE<br><br>No condomínio possui:<br>+ Portaria e Segurança 24 horas<br>+ Academia<br>+ Bosque com área de reserva e nascente <br>+ Lagos<br>+ Quiosque Central<br>+ Empório<br>+ Serviço de Jardinagem já incluso no Condomínio<br>+ Pista de caminhada<br>+ Quadras poliesportiva<br>+ Feirinha',
#         4.0, True, nan, 1.0, 31.0, 339.0, 'RESIDENTIAL'],
#        ['', 12000, 'casas-de-condominio', 'Tremembé', 'Guedes',
#         'São Paulo', 18.0, 30.0,
#         'A casa de condomínio está localizado no bairro Guedes tem 1058 metros quadrados com 30 quartos sendo 15 suites e 18 banheiros<br>Possui playground, espaço para festas, academia, espaço gourmet.<br>Vai lhe possibilitar curtir os dias mais quentes na piscina.Espaço reservado para preparar o seu churrasco.<br>Encontra-se em um condomínio protegido por muros.',
#         24.0, True, 101.0, 380.0, 15.0, 1058.0, 'RESIDENTIAL']],
#       dtype=object)

# %%
data.at[5247, 'listing.suites'] = 4
data.at[53905, 'listing.suites'] = 3
data.at[45887, 'listing.suites'] = 1

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.suites'].notnull()].query('imvl_type == "quitinetes"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "flat"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "studio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-vila"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "apartamentos"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "cobertura"')['listing.suites'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()   
plt.show()

# %%
data.query('imvl_type == "quitinetes" and `listing.suites`> 2')['listing.suites']
# Out:
# 19037    10.0
# 41097     3.0
# 42292     8.0
# 45459    19.0
# Name: listing.suites, dtype: float64

# %%
# lendo a descrição do anuncio eles possuem apenas 1 suite

data.at[19324, 'listing.suites'] = 1
data.at[41479, 'listing.suites'] = 1
data.at[42680, 'listing.suites'] = 1

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.suites'].notnull()].query('imvl_type == "quitinetes"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "flat"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "studio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-vila"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "apartamentos"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "cobertura"')['listing.suites'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()   
plt.show()

# %%
data.query('imvl_type == "studio" and `listing.suites`> 4')
# Out:
#       PADRAO  ALUGUEL imvl_type listing.address.city  \
# 48267             570    studio              Goiânia
#
#       listing.address.neighborhood listing.address.state  listing.bathrooms  \
# 48267           Setor Sol Nascente                 Goiás                1.0
#
#        listing.bedrooms                                listing.description  \
# 48267               1.0  Locação direta com Proprietário sem muita buro...
#
#        listing.parkingSpaces  listing.pricingInfo.isSale  \
# 48267                    1.0                        True
#
#        listing.pricingInfo.monthlyCondoFee  listing.pricingInfo.yearlyIptu  \
# 48267                                  NaN                             NaN
#
#        listing.suites  listing.usableAreas listing.usageTypes
# 48267            10.0                 35.0        RESIDENTIAL

# %%
# Pelo tamanho e valor estou assumindo que seja 1 suite
data.at[48757, 'listing.suites'] = 1

# %% [markdown]
# Resultado

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.suites'].notnull()].query('imvl_type == "quitinetes"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "flat"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "studio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-vila"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "apartamentos"')['listing.suites'], 
              data[data['listing.suites'].notnull()].query('imvl_type == "cobertura"')['listing.suites'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %% [markdown]
# ### Área útil

# %%
fig = plt.figure(figsize=(12, 8))
plt.boxplot([data.query('imvl_type == "quitinetes"')['listing.usableAreas'],
             data.query('imvl_type == "flat"')['listing.usableAreas'],
             data.query('imvl_type == "studio"')['listing.usableAreas'],
             data.query('imvl_type == "casas"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-vila"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-condominio"')['listing.usableAreas'],
             data.query('imvl_type == "apartamentos"')['listing.usableAreas'],
             data.query('imvl_type == "cobertura"')['listing.usableAreas'], ],
            labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura']
            )
plt.grid()

# %%
data.query('`listing.usableAreas` > 10000')
# Out:
#       PADRAO  ALUGUEL            imvl_type listing.address.city  \
# 5192             3800  casas-de-condominio              Limeira
# 7527             1700                casas              Limeira
# 8379              900                casas              Limeira
# 8439             1100                casas              Limeira
# 8451             1200                casas              Limeira
# 9092             2300                casas              Limeira
# 9113             2000                casas           Rio Branco
# 9196              800                casas              Limeira
# 9363              400                casas              Limeira
# 10026            2100                casas              Limeira
# 12392            2000            cobertura              Resende
# 23627            3500  casas-de-condominio       Ribeirão Preto
# 23707            3600  casas-de-condominio              Limeira
# 30257            1550            cobertura            São Paulo
# 31287           12000            cobertura               Franca
# 57428            6850  casas-de-condominio             Curitiba
# 64275            1600                casas             Barretos
# 65210            4500                casas       Rio de Janeiro
#
#       listing.address.neighborhood listing.address.state  listing.bathrooms  \
# 5192                        normal             São Paulo                2.0
# 7527                  Vila Queiroz             São Paulo                1.0
# 8379                     Vila Piza             São Paulo                1.0
# 8439                        normal             São Paulo                1.0
# 8451            Jardim Piratininga             São Paulo                1.0
# 9092              Jardim Montezuma             São Paulo                1.0
# 9113                Alto Alegre \t                  Acre                2.0
# 9196             Jardim Ouro Verde             São Paulo                1.0
# 9363             Jardim Ouro Verde             São Paulo                1.0
# 10026                       Centro             São Paulo                1.0
# 12392            Morada do Castelo        Rio de Janeiro                3.0
# 23627          Recreio das Acácias             São Paulo                4.0
# 23707   Jardim Colinas de Sao Joao             São Paulo                1.0
# 30257                    Jabaquara             São Paulo                2.0
# 31287        Residencial Amazonas              São Paulo                5.0
# 57428                São Francisco                Paraná                2.0
# 64275                 São Salvador             São Paulo                3.0
# 65210                      Taquara        Rio de Janeiro                3.0
#
#        listing.bedrooms                                listing.description  \
# 5192                3.0  03 dormitórios, sendo 03 suites, sala com 2 am...
# 7527                3.0  03 dormitorios c armarios sendo 01 suite, sala...
# 8379                3.0  03 dormitorios, sala, copa, cozinha, banheiro ...
# 8439                3.0  03 dormitórios, sala, cozinha e área de serviç...
# 8451                3.0  03 dormitórios c armarios sendo uma suite, sal...
# 9092                3.0  03 dormitórios c armários, sendo 01 suite, 02 ...
# 9113                3.0  Aluguel: 2.000,00 / mês<br>Total: 2.000,00 / m...
# 9196                1.0  01 dormitorio, sala, cozinha, área de serviço,...
# 9363                1.0  01 dormitório, sala, cozinha, área de serviço,...
# 10026               2.0  02 dormitorios, sala, cozinha, area de serviço...
# 12392               3.0  Oportunidade de Cobertura á venda ou locação n...
# 23627               3.0  Casa em condomínio fechado com 3 suítes com ar...
# 23707               3.0  03 dormitórios sendo 01 suíte c bganheira de h...
# 30257               2.0  ALUGO APARTAMENTO COBERTURA COM SACADA AREA DE...
# 31287               4.0                    .RINOCER em expansão pelo mundo
# 57428               5.0  41 Imóveis aluga casa na região de Curitiba<br...
# 64275               3.0  2 dormitórios, 1 banheiro social, sala, copa, ...
# 65210               3.0  Andreata Gestão Imobiliária aluga casa na Estr...
#
#        listing.parkingSpaces  listing.pricingInfo.isSale  \
# 5192                     2.0                        True
# 7527                     2.0                        True
# 8379                     1.0                        True
# 8439                     1.0                        True
# 8451                     1.0                        True
# 9092                     3.0                        True
# 9113                    10.0                        True
# 9196                     1.0                        True
# 9363                     0.0                        True
# 10026                    1.0                        True
# 12392                    2.0                        True
# 23627                    4.0                        True
# 23707                    3.0                        True
# 30257                    1.0                        True
# 31287                    6.0                        True
# 57428                    3.0                        True
# 64275                    3.0                        True
# 65210                   21.0                        True
#
#        listing.pricingInfo.monthlyCondoFee  listing.pricingInfo.yearlyIptu  \
# 5192                                 330.0                             NaN
# 7527                                   NaN                             NaN
# 8379                                   NaN                             NaN
# 8439                                   NaN                             NaN
# 8451                                   NaN                             NaN
# 9092                                   NaN                             NaN
# 9113                                   NaN                             NaN
# 9196                                   NaN                             NaN
# 9363                                   NaN                             NaN
# 10026                                  NaN                             NaN
# 12392                                684.0                             NaN
# 23627                                  NaN                             NaN
# 23707                                  NaN                             NaN
# 30257                                622.0                           335.0
# 31287                                  NaN                             NaN
# 57428                                  NaN                             NaN
# 64275                                  NaN                           170.0
# 65210                                  NaN                           380.0
#
#        listing.suites  listing.usableAreas listing.usageTypes
# 5192              3.0            9999999.0        RESIDENTIAL
# 7527              1.0            9999999.0        RESIDENTIAL
# 8379              NaN            9999999.0        RESIDENTIAL
# 8439              NaN            9999999.0        RESIDENTIAL
# 8451              1.0            9999999.0        RESIDENTIAL
# 9092              1.0            9999999.0        RESIDENTIAL
# 9113              1.0              20000.0        RESIDENTIAL
# 9196              NaN            9999999.0        RESIDENTIAL
# 9363              NaN            9999999.0        RESIDENTIAL
# 10026             NaN            9999999.0        RESIDENTIAL
# 12392             1.0              15704.0        RESIDENTIAL
# 23627             3.0              17220.0        RESIDENTIAL
# 23707             1.0            9999999.0        RESIDENTIAL
# 30257             1.0              13278.0        RESIDENTIAL
# 31287             4.0              52257.0        RESIDENTIAL
# 57428             1.0              30357.0        RESIDENTIAL
# 64275             0.0              18437.0        RESIDENTIAL
# 65210             1.0              60000.0        RESIDENTIAL

# %%
for index, item in data[data['listing.usableAreas'] > 10000].iterrows():
    if ('m²' or 'm2') in item['listing.description']:
        print(index, item['listing.description'])
# Out:
# 9113 Aluguel: 2.000,00 / mês<br>Total: 2.000,00 / mês<br><br>20000m² (dois mil metros quadrados) de terreno e 250m² (duzentos e cinquenta metros quadrados) de construção, contempla-se nessa construção uma casa com, garagem coberta para 01 (um) veículos, 01 (uma) sala mobiliada , 01(uma) cozinha mobiliada, despensa e lavanderia mobiliada, 03 (três) dormitórios, sendo um suíte.<br>Na parte de cima da casa temos; uma sala reservada! aos fundos temos um grande quintal com galinha, igarapé e açude com deck. <br>Simplesmente muito aconchegante o imóvel!!!!!
# 64275 2 dormitórios, 1 banheiro social, sala, copa, cozinha com armários, laje, piso frio e taco, área de serviço coberta, 1 banheiro externo. Edícula com 1 dormitório, 1 banheiro social, sala e cozinha conjugada, despejo.<br>Área do terreno: 250,00 m²<br>Área construída: 184,37 m²

# %%
# Altera manualmente os que constam na descrição

data.at[9133, 'listing.usableAreas'] = 250
data.at[64962, 'listing.usableAreas'] = 184

# %%
# Remove os demais

data.drop(data.query('`listing.usableAreas` > 10000').index, inplace=True)

# %%
fig = plt.figure(figsize=(12, 8))
plt.boxplot([data.query('imvl_type == "quitinetes"')['listing.usableAreas'],
             data.query('imvl_type == "flat"')['listing.usableAreas'],
             data.query('imvl_type == "studio"')['listing.usableAreas'],
             data.query('imvl_type == "casas"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-vila"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-condominio"')['listing.usableAreas'],
             data.query('imvl_type == "apartamentos"')['listing.usableAreas'],
             data.query('imvl_type == "cobertura"')['listing.usableAreas'], ],
            labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura']
            )
plt.grid()

# %%
for index, item in data[data['listing.usableAreas'] > 2000].iterrows():
    if ('m²' or 'm2') in item['listing.description']:
        print(index, item['listing.description'])
# Out:
# 5756 Oportunidade! Conheça esta deslumbrante Casa em condomínio fechado, no alto do Cascatinha, vista panorâmica da cidade e montanhas com 800 de construção e 3.200 de terreno. Muito verde e segurança. Casa com 550 metros de construção sendo sala toda em madeira em 3 ambientes, muito ampla e confortável. Salão com lareira e fino acabamento, com amplas varandas. Suíte com closet,hidro e lareira exclusiva, banheiro social,cozinha planejada e área de serviço. Casa de caseiro com 65m² de construção sendo 2 quartos sendo 1 suíte, sala,cozinha, banheiro social e área de serviço. Área de lazer com 200m² , sendo 2 saunas à seco e vapor. Amplo salão com churrasqueira,fogão a lenha, forno para pizza , bancada com pia. Estudamos permuta!Agende sua visita!
# 53247 Excelente casa com 04 quartos, toda mobiliada, em condomínio fechado, seguro, tranquilo e com privacidade, estrutura em madeira e alvenaria, em terreno plano de 4.020m²; com pomar repleto de frutas variadas, paisagismo com flores e plantas ornamentais.<br> <br><br><b>Casa:</b><br> <br>- Sala de estar;<br> <br>- Sala de jantar;<br> <br>- Varanda 360º;<br> <br>- Cozinha;<br> <br>- 04 Quartos, sendo 02 suítes e 02 semi-suítes;<br> <br>- Banho social
data.at[67079, 'listing.usableAreas'] = 263
data.at[66818, 'listing.usableAreas'] = 640
data.at[60826, 'listing.usableAreas'] = 411
data.at[58694, 'listing.usableAreas'] = 400
data.at[57700, 'listing.usableAreas'] = 790
data.at[57646, 'listing.usableAreas'] = 800

# %%
data.drop(data.query('`listing.usableAreas` > 1060').index, inplace=True)

# %%
fig = plt.figure(figsize=(12, 8))
plt.boxplot([data.query('imvl_type == "quitinetes"')['listing.usableAreas'],
             data.query('imvl_type == "flat"')['listing.usableAreas'],
             data.query('imvl_type == "studio"')['listing.usableAreas'],
             data.query('imvl_type == "casas"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-vila"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-condominio"')['listing.usableAreas'],
             data.query('imvl_type == "apartamentos"')['listing.usableAreas'],
             data.query('imvl_type == "cobertura"')['listing.usableAreas'], ],
            labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura']
            )
plt.grid()

# %%
data.drop(data.query('imvl_type == "quitinetes" and `listing.usableAreas` > 60').index, inplace=True)

# %% [markdown]
# Resultado

# %%
fig = plt.figure(figsize=(12, 8))
plt.boxplot([data.query('imvl_type == "quitinetes"')['listing.usableAreas'],
             data.query('imvl_type == "flat"')['listing.usableAreas'],
             data.query('imvl_type == "studio"')['listing.usableAreas'],
             data.query('imvl_type == "casas"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-vila"')['listing.usableAreas'],
             data.query('imvl_type == "casas-de-condominio"')['listing.usableAreas'],
             data.query('imvl_type == "apartamentos"')['listing.usableAreas'],
             data.query('imvl_type == "cobertura"')['listing.usableAreas'], ],
            labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura']
            )
plt.grid()

# %% [markdown]
# ### IPTU

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "quitinetes"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "flat"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "studio"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "casas"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "casas-de-vila"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "apartamentos"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "cobertura"')['listing.pricingInfo.yearlyIptu'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %%
data.drop(data.query('`listing.pricingInfo.yearlyIptu` > 30000').index, inplace=True)

# %% [markdown]
# Resultado

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "quitinetes"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "flat"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "studio"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "casas"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "casas-de-vila"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "apartamentos"')['listing.pricingInfo.yearlyIptu'], 
              data[data['listing.pricingInfo.yearlyIptu'].notnull()].query('imvl_type == "cobertura"')['listing.pricingInfo.yearlyIptu'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %% [markdown]
# ### Vagas

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "quitinetes"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "flat"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "studio"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas-de-vila"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "apartamentos"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "cobertura"')['listing.parkingSpaces'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %%
# data.query('`listing.parkingSpaces` > 40')['listing.description'].values

for index, item in data[data['listing.parkingSpaces'] > 40].iterrows():
    print(index, item['listing.parkingSpaces'],item['listing.description'])
# Out:
# 18876 243.0 F&M IMÓVEIS, A SINTONIA CERTA PARA SEU IMÓVEL<br><br>- QMSW 05 - ED. MONT SERRAT<br>- Kitinete em ótima localização, na entrada do sudoeste, composta de:<br><br>*Sala e quarto em vão livre, armário no quarto<br>* Ar condicionado no quarto<br>*Cozinha com frigobar e fogão cooktop;<br>*Tanque de cerâmica;<br>*Banheiro social com box de banheiro<br>*Vaga de garagem no subsolo. 9 vaga nº 243 no subsolo<br><br>Estrutura condominial;<br><br>*Portaria 24hs; *Academia; *Salão de festas com Home Cinema;<br>*Lavanderia terceirizada.<br>- valor do condomínio - 250,00<br>- IPTU/2020 4 cotas de 159,38<br><br>O locatário deverá contratar seguro incêndio para o imóvel.<br><br>Modalidades de garantias aceitas:<br>Fiadores<br>Seguro fiança<br>Título de capitalização<br>Carta fiança (consulte-nos sobre as cartas fiança aceitas)<br><br>*O valor do condomínio está sujeito a alterações e deverá ser verificado pelo interessado junto à administração do edifício.<br><br>Entregamos as chaves de segunda a sexta-feira, de 08h às 17h.<br><br>LIGUE AGORA E FAÇA UMA VISITA!<br>Fone: <br>whatsapp -
# 35232 403.0 Apartamento dois dormitórios, sala, sacada com churrasqueira, banheiro social com armário, box, chuveiro, cozinha com armários planejados, fogão cooktop, forno elétrico, área de serviço, garagem privativa descoberta, condomínio com playground, salão de festas e portaria.<br> Taxa de IPTU/cota única R$: 700,20<br><br>(chave 08)<br>
# 45766 62.0 *** LOCALIZADO NO BAIRRO BOM FIM *** Ótimo JK amplo com 41m² de área, sala, piso carpete, banheiro social, cozinha, área de serviço. Condomínio com elevador, terraço com churrasqueiras, vista panorâmica. Próximo ao Zaffari da Fernandes Vieira. Agende agora á sua visita!
# 46138 47.0 . ]]>
# 56181 42.0 A casa encontra-se em localização privilegiada, mobiliada, banheira de hidromassagem, Box, Armários embutidos no quarto, Armários nos banheiros, Armários na cozinha, Ar condicionado, Chuveiro a gás, Fogão incluso, Geladeira inclusa, Closet, Mesas e cadeiras de escritório, Jardim, Quartos e corredores com portas amplas, Quintal e Área de serviço completa!
# 59938 50.0 Excelente casa para aluguel 5.000,00-4 dormitórios climatizados (sendo uma suíte)-3 banheiros-Sala dois ambientes-Cozinha-Área de serviço-Escritório-Edícula com cozinha-Murada-Área construída 280m²-Portão social-2 portões para entrada de veículos-Estacionamento para 50 carrosAgende sua visita!CONTATO: <br>-Cod:CA4700 -Rev.23Mai

# %%
# Corrigindo manualmente

data.at[19162, 'listing.parkingSpaces'] = 1
data.at[35606, 'listing.parkingSpaces'] = 1

# %%
data.drop(data.query('`listing.parkingSpaces` > 50').index, inplace=True)

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "quitinetes"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "flat"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "studio"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas-de-vila"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "apartamentos"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "cobertura"')['listing.parkingSpaces'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %%
data.drop(data.query('`listing.parkingSpaces` > 12').index, inplace=True)

# %% [markdown]
# Resultado

# %%
fig = plt.figure(figsize=(12, 6))
plt.boxplot( [data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "quitinetes"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "flat"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "studio"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas-de-vila"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "casas-de-condominio"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "apartamentos"')['listing.parkingSpaces'], 
              data[data['listing.parkingSpaces'].notnull()].query('imvl_type == "cobertura"')['listing.parkingSpaces'] ],
             labels=['quitinetes', 'flat', 'studio', 'casas', 'casas-de-vila', 'casas-de-condominio','apartamentos', 'cobertura'])
plt.grid()

# %% [markdown]
# ## Valores nulos

# %%
data.isnull().sum()
# Out:
# PADRAO                                     2
# ALUGUEL                                    2
# imvl_type                                  2
# listing.address.city                       3
# listing.address.neighborhood             143
# listing.address.state                      5
# listing.bathrooms                          5
# listing.bedrooms                          39
# listing.description                      179
# listing.parkingSpaces                   5091
# listing.pricingInfo.isSale                 2
# listing.pricingInfo.monthlyCondoFee    21762
# listing.pricingInfo.yearlyIptu         21450
# listing.suites                         10760
# listing.usableAreas                        1
# listing.usageTypes                         2
# dtype: int64

# %% [markdown]
# ### Condomínio

# %%
# Considerando os valores nulos como sem condominio

data['listing.pricingInfo.monthlyCondoFee'].fillna(0, inplace=True)

# %% [markdown]
# ### Quartos

# %%
data[data['listing.bedrooms'].isnull()]['listing.description'].values
# Out:
# array(['Casa comercial de esquina com 12 salas, copa, 3 depósitos, 2 lavabos, piso porcelanato, 3 pavimentos. Sol da tarde.<br>O Centro de Floripa é bem estruturado e concentra todos os principais serviços da cidade, além de possuir escolas, restaurantes, shoppings e academias. O terminal do centro - TICEN faz parte dos sistema integrado de transportes de Florianópolis e de lá é possível pegar ônibus para todas as regiões da Ilha, como também para o Continente.',
#        'Casa comercial com 327 m²contendo 10 salas, 4 banheiros, piso taco de madeira e 2 vagas de garagem. Ideal para você que deseja abrir ou expandir o seu negócio.<br><br>*** BONIFICAÇÃO DE 1.000,00 nos primeiros 12 meses de locação*** <br><br>O Centro de Floripa é bem estruturado e concentra todos os principais serviços da cidade, além de possuir escolas, restaurantes, shoppings e academias. O terminal do centro - TICEN faz parte dos sistema integrado de transportes de Florianópolis e de lá é possível pegar ônibus para todas as regiões da Ilha, como também para o Continente.',
#        'Excelente imóvel comercial possuindo 7 salas, cozinha, 2 banheiros, área de serviço, espaço gourmet e 10 vagas de garagem. Ótima localização próximo a supermercados, comércios em geral, avenida Capitão Mario Toledo de Camargo, estádio Bruno Jose Daniel, atrium shopping e fácil acesso para o centro de Santo André. Não perca tempo e agende já sua visita com um de nossos promotores!!<br><br>Origem e resgate histórico<br>No passado, o território que hoje abriga a Vila Humaitá integrava o famoso Sítio dos Ribeiros, que foi registrado na Paróquia de São Bernardo, por volta do ano de 1856. Essas informações são citadas por Iberê Luiz Di Tizio, em sua tese: "Santo André causa toponímica na denominação de seus bairros", apresentada à Faculdade de Filosofia, Letras e Ciências Humanas, da USP (Universidade de São Paulo), em 2009.<br>Ess
#        'Pontos de Referência: Flor de Quintal, Sforno Pizzaria e Fabulosa Bakery. <BR><BR>Excelente casa comercial em ótima localização e próxima do Centro de Curitiba.<BR><BR><BR>Contendo:<BR><BR>- Recepção na parte inferior.<BR>- 11 Salas.<BR>- 06 Lavabos.<BR>- Cozinha com pia.<BR>- Currasqueira.<BR>- 08 Vagas de garagem sendo para 05 carros livres ou 08 carros presos.<BR>- Ar condicionado.<BR>- Cerca elétrica.<BR><BR><BR>',
#        'Excelente casa comercial para alugar no bairro Vila Nova em Itu. Localização privilegiada!!!<br>Ótimo ponto para clínica ou consultório. Amplo salão com três ambientes + cinco salas, cinco banheiros total, quintal com área de serviço, depósito, cozinha com banheiro, três vagas de garagem descobertas.<br>Aceita-se fiador e seguro fiança.<br>R$5547,30 incluso IPTU.<br>Fale conosco: -',
#        'RA Amil Aluga:<br>Casa Comercial com 457m², com 13 Salas, 6 banheiros, Garagem para 4 carros, no Jardim Alvorada, Zona Oeste<br><br>Salas<br>13 salas<br><br>Banheiros<br>6 Banheiros<br><br>Garagem<br>4 carros<br>Fale conosco: -',
#        'Esse imóvel é ideal para comércio. Por exemplo um restaurante. Ele fica a 400ms da Av Itália. <br>Na casa da frente , tem 02 banheiro, una cozinha enorme com armários e 2 salas enormes. <br>Na edícula tem espaço para cozinha industrial , com pia grande e bancada de mármore. Mais um banheiro e um cômodo.<br>Fale conosco: -',
#        'Casa térrea de esquina com sala de estar, sala de jantar, cozinha planejada, 1 banheiro social, 3 dormitórios sendo 1 suíte, área de serviço e varanda.<br><br>Acabamento Interno: Cozinha modulada. Áreas molhadas com revestimento até o teto.<br><br>Descrição do Bairro: Infraestrutura completa em comércios e serviços.<br><br>Descrição do Entorno: Próximo à hipermercados, escolas, farmácias, posto de combustível e transporte público. Fácil acesso ao Centro de Votorantim e Rod. Raposo Tavares.',
#        'Casa comercial com duas salas na parte superior, uma cozinha dois ambientes, um banheiro social e três salas na parte inferior<br><br>Detalhes do acabamento: duas salas e entrada em piso de madeira, cozinha em piso cerâmico<br>Na parte inferior todos as salas em contra piso e todos os cômodos com forro pvc.<br><br>Descrição do entorno: Próximo a mercados, oficinas, farmácias ,comercio em geral e fácil acesso a avenida General Carneiro',
#        'Casa Comercial para alugar no Bairro Rio Branco em Porto Alegre. Possui aproximadamente 250m² de área útil, 02 andares, térreo com 02 salas, 01 banheiro no térreo, segundo piso com 04 salas e mais 01 banheiros, piso parquet, garagem coberta para ate 03 carros pequenos, amplo pátio, cozinha, fundos com sala auxiliar com possibilidade para uma área de lazer externa, casa de esquina, próximo da Avenida Protasio Alves.',
#        nan, nan], dtype=object)

# %%
# A maioria dos quartos nulos são imoveis anunciados como comercial então tem salas no lugar de quartos
data.dropna(subset=['listing.bedrooms'], inplace=True)

# %%
data.query('`listing.bedrooms` == 0')['imvl_type'].value_counts()
# Out:
# quitinetes             1260
# studio                   12
# casas-de-vila             8
# flat                      8
# apartamentos              2
# casas-de-condominio       2
# casas                     2
# Name: imvl_type, dtype: int64

# %%
# Considera quitinetes studios e flats com valor 0 como 1 quarto
for index, row in data.query('`listing.bedrooms` == 0 and (imvl_type == "quitinetes" or imvl_type == "studio" or imvl_type == "flat")').iterrows():
    data.at[index, 'listing.bedrooms'] = 1

# %%
data.drop(data.query('`listing.bedrooms` == 0').index, inplace=True)

# %% [markdown]
# ### Banheiros

# %%
data.isna().sum()
# Out:
# PADRAO                                     0
# ALUGUEL                                    0
# imvl_type                                  0
# listing.address.city                       1
# listing.address.neighborhood             140
# listing.address.state                      3
# listing.bathrooms                          3
# listing.bedrooms                           0
# listing.description                      176
# listing.parkingSpaces                   5074
# listing.pricingInfo.isSale                 0
# listing.pricingInfo.monthlyCondoFee        0
# listing.pricingInfo.yearlyIptu         21427
# listing.suites                         10723
# listing.usableAreas                        1
# listing.usageTypes                         0
# dtype: int64

# %%
data.query('`listing.bathrooms` == 0')['imvl_type'].value_counts().sum()
# Out:
# 607

# %%
count = 0
for index, row in data.query('`listing.bathrooms` == 0').iterrows():
    if ("1 BANH" or "UM BANH" or "1 WC" or "UM WC") in row['listing.description'].upper():
        data.at[index, 'listing.bathrooms'] = 1
        count +=1
    if ("2 BANH" or "DOIS BANH" or "2 WC" or "DOIS WC") in row['listing.description'].upper():
        data.at[index, 'listing.bathrooms'] = 2
        count +=1
    if ("3 BANH" or "TRES BANH" or "TRÊS BANH" or "3 WC" or "TRES WC" or "TRÊS WC") in row['listing.description'].upper():
        data.at[index, 'listing.bathrooms'] = 3
        count +=1
    if ("4 BANH" or "QUATRO BANH" or "4 WC" or "QUATRO WC") in row['listing.description'].upper():
        data.at[index, 'listing.bathrooms'] = 4
        count +=1
print(count)
# Out:
# 63

# %%
data.dropna(subset=['listing.bathrooms'], inplace=True)

# %%
# Completa os valores 0 com a media do tipo de imovel

for index, row in data.query('`listing.bathrooms` == 0').iterrows():
    type = row['imvl_type']
    mean = data.query('`listing.bathrooms` > 0 and imvl_type == @type')['listing.bathrooms'].mean()
    data.at[index, 'listing.bathrooms'] = int(mean)

# %%
data.isna().sum()
# Out:
# PADRAO                                     0
# ALUGUEL                                    0
# imvl_type                                  0
# listing.address.city                       1
# listing.address.neighborhood             140
# listing.address.state                      3
# listing.bathrooms                          0
# listing.bedrooms                           0
# listing.description                      176
# listing.parkingSpaces                   5072
# listing.pricingInfo.isSale                 0
# listing.pricingInfo.monthlyCondoFee        0
# listing.pricingInfo.yearlyIptu         21425
# listing.suites                         10720
# listing.usableAreas                        0
# listing.usageTypes                         0
# dtype: int64

# %% [markdown]
# ### Suites

# %%
data['listing.suites'].isna().sum()
# Out:
# 10720

# %%
count = 0
for index, row in data[data['listing.suites'].isnull()].iterrows():
    if ("1 SUIT" or "UMA SUIT" or "UM SUIT" or "1 SUÍT" or "UMA SUÍT" or "UM SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 1
        count +=1
    if ("2 SUIT" or "DOIS SUIT" or "2 SUÍT" or "DOIS SUÍT" or "DUAS SUIT" or "DUAS SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 2
        count +=1
    if ("3 SUIT" or "TRES SUIT" or "TRÊS SUIT" or "3 SUÍT" or "TRES SUÍT" or "TRÊS SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 3
        count +=1
    if ("4 SUIT" or "QUATRO SUIT" or "4 SUÍT" or "QUATRO SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 4
        count +=1
    if ("5 SUIT" or "CINCO SUIT" or "5 SUÍT" or "CINCO SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 5
        count +=1
    if ("6 SUIT" or "SEIS SUIT" or "6 SUÍT" or "SEIS SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 6
        count +=1
print(count)
# Out:
# 45

# %%
count = 0
for index, row in data.query('`listing.suites` == 0').iterrows():
    if ("1 SUIT" or "UMA SUIT" or "UM SUIT" or "1 SUÍT" or "UMA SUÍT" or "UM SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 1
        count +=1
    if ("2 SUIT" or "DOIS SUIT" or "2 SUÍT" or "DOIS SUÍT" or "DUAS SUIT" or "DUAS SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 2
        count +=1
    if ("3 SUIT" or "TRES SUIT" or "TRÊS SUIT" or "3 SUÍT" or "TRES SUÍT" or "TRÊS SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 3
        count +=1
    if ("4 SUIT" or "QUATRO SUIT" or "4 SUÍT" or "QUATRO SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 4
        count +=1
    if ("5 SUIT" or "CINCO SUIT" or "5 SUÍT" or "CINCO SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 5
        count +=1
    if ("6 SUIT" or "SEIS SUIT" or "6 SUÍT" or "SEIS SUÍT") in str(row['listing.description']).upper():
        data.at[index, 'listing.suites'] = 6
        count +=1
print(count)
# Out:
# 41

# %%
# Corrige os imoveis que contam o banheiro da suite na quantidade de banheiros

count = 0
for index, row in data.query('`listing.suites` > `listing.bathrooms`').iterrows():
    data.at[index, 'listing.bathrooms'] = row['listing.suites']
    count += 1
print(count)
# Out:
# 917

# %%
for index, row in data[data['listing.suites'].isnull()].iterrows():
    type = row['imvl_type']
    mean = data.query('`listing.suites` > -1 and imvl_type == @type')['listing.suites'].mean()
    data.at[index, 'listing.suites'] = int(mean)

# %% [markdown]
# ### Área útil

# %%
data.query('`listing.usableAreas` == 0')
# Out:
#       PADRAO  ALUGUEL            imvl_type listing.address.city  \
# 4160           2300.0  casas-de-condominio             São Luís
# 23561          3300.0  casas-de-condominio     Lauro de Freitas
#
#       listing.address.neighborhood listing.address.state  listing.bathrooms  \
# 4160                   Olho d'Água              Maranhão                3.0
# 23561                      Miragem                 Bahia                4.0
#
#        listing.bedrooms                                listing.description  \
# 4160                4.0  IMPERDIVEL----ALUGA Casa em condomínio, 4 dorm...
# 23561               4.0  casa com 44 sendo 3 suites, cozinha com armari...
#
#        listing.parkingSpaces listing.pricingInfo.isSale  \
# 4160                     3.0                       True
# 23561                    2.0                       True
#
#        listing.pricingInfo.monthlyCondoFee  listing.pricingInfo.yearlyIptu  \
# 4160                                   0.0                             NaN
# 23561                                  0.0                             NaN
#
#        listing.suites  listing.usableAreas listing.usageTypes
# 4160              1.0                  0.0        RESIDENTIAL
# 23561             3.0                  0.0        RESIDENTIAL

# %%
data.at[23882, 'listing.usableAreas'] = 44

# %%
data.drop(data.query('`listing.usableAreas` == 0').index, inplace=True)

# %%
data.isna().sum()
# Out:
# PADRAO                                     0
# ALUGUEL                                    0
# imvl_type                                  0
# listing.address.city                       1
# listing.address.neighborhood             140
# listing.address.state                      3
# listing.bathrooms                          0
# listing.bedrooms                           0
# listing.description                      176
# listing.parkingSpaces                   5072
# listing.pricingInfo.isSale                 0
# listing.pricingInfo.monthlyCondoFee        0
# listing.pricingInfo.yearlyIptu         21423
# listing.suites                             0
# listing.usableAreas                        0
# listing.usageTypes                         0
# dtype: int64

# %% [markdown]
# ### IPTU

# %%
# Assumindo que os iptu nulos são isentos de iptu

data['listing.pricingInfo.yearlyIptu'].fillna(0, inplace=True)

# %%
data.isna().sum()
# Out:
# PADRAO                                    0
# ALUGUEL                                   0
# imvl_type                                 0
# listing.address.city                      1
# listing.address.neighborhood            140
# listing.address.state                     3
# listing.bathrooms                         0
# listing.bedrooms                          0
# listing.description                     176
# listing.parkingSpaces                  5072
# listing.pricingInfo.isSale                0
# listing.pricingInfo.monthlyCondoFee       0
# listing.pricingInfo.yearlyIptu            0
# listing.suites                            0
# listing.usableAreas                       0
# listing.usageTypes                        0
# dtype: int64

# %% [markdown]
# ### Vagas

# %%
# Procurando a quantidade de vagas na descrição

count = 0
for index, row in data[data['listing.parkingSpaces'].isnull()].iterrows():
    if ("1 VAG" or "UMA VAG") in str(row['listing.description']).upper():
        data.at[index, 'listing.parkingSpaces'] = 1
        count +=1
    if ("2 VAG" or "DUAS VAG") in str(row['listing.description']).upper():
        data.at[index, 'listing.parkingSpaces'] = 2
        count +=1
    if ("3 VAG" or "TRES VAG" or "TRÊS VAG") in str(row['listing.description']).upper():
        data.at[index, 'listing.parkingSpaces'] = 3
        count +=1
    if ("4 VAG" or "QUATRO VAG") in str(row['listing.description']).upper():
        data.at[index, 'listing.parkingSpaces'] = 4
        count +=1
    if ("5 VAG" or "CINCO VAG") in str(row['listing.description']).upper():
        data.at[index, 'listing.parkingSpaces'] = 5
        count +=1
    if ("6 VAG" or "SEIS VAG") in str(row['listing.description']).upper():
        data.at[index, 'listing.parkingSpaces'] = 6
        count +=1
print(count)
# Out:
# 211

# %%
# Assumindo que as vagas nulas são imoveis sem vagas

data['listing.parkingSpaces'].fillna(0, inplace=True)

# %%
data.isna().sum()
# Out:
# PADRAO                                   0
# ALUGUEL                                  0
# imvl_type                                0
# listing.address.city                     1
# listing.address.neighborhood           140
# listing.address.state                    3
# listing.bathrooms                        0
# listing.bedrooms                         0
# listing.description                    176
# listing.parkingSpaces                    0
# listing.pricingInfo.isSale               0
# listing.pricingInfo.monthlyCondoFee      0
# listing.pricingInfo.yearlyIptu           0
# listing.suites                           0
# listing.usableAreas                      0
# listing.usageTypes                       0
# dtype: int64

# %% [markdown]
# ### Estado, cidade e bairro

# %%
data.dropna(subset=['listing.address.city', 'listing.address.state', 'listing.address.neighborhood'], inplace=True)
data.isna().sum()
# Out:
# PADRAO                                   0
# ALUGUEL                                  0
# imvl_type                                0
# listing.address.city                     0
# listing.address.neighborhood             0
# listing.address.state                    0
# listing.bathrooms                        0
# listing.bedrooms                         0
# listing.description                    176
# listing.parkingSpaces                    0
# listing.pricingInfo.isSale               0
# listing.pricingInfo.monthlyCondoFee      0
# listing.pricingInfo.yearlyIptu           0
# listing.suites                           0
# listing.usableAreas                      0
# listing.usageTypes                       0
# dtype: int64

# %%
data = data.drop(['listing.description'], axis=1)

# %% [markdown]
# # Criação dos sets de teste e treino

# %%
data.notnull().sum()
# Out:
# PADRAO                                 67567
# ALUGUEL                                67567
# imvl_type                              67567
# listing.address.city                   67567
# listing.address.neighborhood           67567
# listing.address.state                  67567
# listing.bathrooms                      67567
# listing.bedrooms                       67567
# listing.parkingSpaces                  67567
# listing.pricingInfo.isSale             67567
# listing.pricingInfo.monthlyCondoFee    67567
# listing.pricingInfo.yearlyIptu         67567
# listing.suites                         67567
# listing.usableAreas                    67567
# listing.usageTypes                     67567
# dtype: int64

# %%
train_set, test_set = train_test_split(data, test_size=0.2, random_state=42)

# %%
data_class = data

# %% [markdown]
# # Exploração e analise dos dados

# %%
data.hist(figsize=(15,10))
plt.show()

# %% [markdown]
# Procurando correlações

# %%
corr_matrix = data.corr(numeric_only=True)
corr_matrix
# Out:
#                                       ALUGUEL  listing.bathrooms  \
# ALUGUEL                              1.000000           0.700410
# listing.bathrooms                    0.700410           1.000000
# listing.bedrooms                     0.594797           0.764740
# listing.parkingSpaces                0.618580           0.688139
# listing.pricingInfo.monthlyCondoFee  0.484236           0.349984
# listing.pricingInfo.yearlyIptu       0.323888           0.285976
# listing.suites                       0.650935           0.809236
# listing.usableAreas                  0.699076           0.791898
#
#                                      listing.bedrooms  listing.parkingSpaces  \
# ALUGUEL                                      0.594797               0.618580
# listing.bathrooms                            0.764740               0.688139
# listing.bedrooms                             1.000000               0.671787
# listing.parkingSpaces                        0.671787               1.000000
# listing.pricingInfo.monthlyCondoFee          0.239972               0.278432
# listing.pricingInfo.yearlyIptu               0.247496               0.246817
# listing.suites                               0.645802               0.614280
# listing.usableAreas                          0.770900               0.726478
#
#                                      listing.pricingInfo.monthlyCondoFee  \
# ALUGUEL                                                         0.484236
# listing.bathrooms                                               0.349984
# listing.bedrooms                                                0.239972
# listing.parkingSpaces                                           0.278432
# listing.pricingInfo.monthlyCondoFee                             1.000000
# listing.pricingInfo.yearlyIptu                                  0.322445
# listing.suites                                                  0.357453
# listing.usableAreas                                             0.301652
#
#                                      listing.pricingInfo.yearlyIptu  \
# ALUGUEL                                                    0.323888
# listing.bathrooms                                          0.285976
# listing.bedrooms                                           0.247496
# listing.parkingSpaces                                      0.246817
# listing.pricingInfo.monthlyCondoFee                        0.322445
# listing.pricingInfo.yearlyIptu                             1.000000
# listing.suites                                             0.243430
# listing.usableAreas                                        0.295157
#
#                                      listing.suites  listing.usableAreas
# ALUGUEL                                    0.650935             0.699076
# listing.bathrooms                          0.809236             0.791898
# listing.bedrooms                           0.645802             0.770900
# listing.parkingSpaces                      0.614280             0.726478
# listing.pricingInfo.monthlyCondoFee        0.357453             0.301652
# listing.pricingInfo.yearlyIptu             0.243430             0.295157
# listing.suites                             1.000000             0.680169
# listing.usableAreas                        0.680169             1.000000

# %% [markdown]
# Combinando atributos

# %%
data['bedrooms_per_usableArea'] = data['listing.bedrooms'] / data['listing.usableAreas']
data['bathrooms_per_bedrooms'] =  data['listing.bathrooms'] / data['listing.bedrooms']

corr_matrix = data.corr(numeric_only=True)
corr_matrix
# Out:
#                                       ALUGUEL  listing.bathrooms  \
# ALUGUEL                              1.000000           0.700410
# listing.bathrooms                    0.700410           1.000000
# listing.bedrooms                     0.594797           0.764740
# listing.parkingSpaces                0.618580           0.688139
# listing.pricingInfo.monthlyCondoFee  0.484236           0.349984
# listing.pricingInfo.yearlyIptu       0.323888           0.285976
# listing.suites                       0.650935           0.809236
# listing.usableAreas                  0.699076           0.791898
# bedrooms_per_usableArea             -0.380266          -0.361000
# bathrooms_per_bedrooms               0.349810           0.560357
#
#                                      listing.bedrooms  listing.parkingSpaces  \
# ALUGUEL                                      0.594797               0.618580
# listing.bathrooms                            0.764740               0.688139
# listing.bedrooms                             1.000000               0.671787
# listing.parkingSpaces                        0.671787               1.000000
# listing.pricingInfo.monthlyCondoFee          0.239972               0.278432
# listing.pricingInfo.yearlyIptu               0.247496               0.246817
# listing.suites                               0.645802               0.614280
# listing.usableAreas                          0.770900               0.726478
# bedrooms_per_usableArea                     -0.262338              -0.364139
# bathrooms_per_bedrooms                      -0.030734               0.229060
#
#                                      listing.pricingInfo.monthlyCondoFee  \
# ALUGUEL                                                         0.484236
# listing.bathrooms                                               0.349984
# listing.bedrooms                                                0.239972
# listing.parkingSpaces                                           0.278432
# listing.pricingInfo.monthlyCondoFee                             1.000000
# listing.pricingInfo.yearlyIptu                                  0.322445
# listing.suites                                                  0.357453
# listing.usableAreas                                             0.301652
# bedrooms_per_usableArea                                        -0.218123
# bathrooms_per_bedrooms                                          0.233693
#
#                                      listing.pricingInfo.yearlyIptu  \
# ALUGUEL                                                    0.323888
# listing.bathrooms                                          0.285976
# listing.bedrooms                                           0.247496
# listing.parkingSpaces                                      0.246817
# listing.pricingInfo.monthlyCondoFee                        0.322445
# listing.pricingInfo.yearlyIptu                             1.000000
# listing.suites                                             0.243430
# listing.usableAreas                                        0.295157
# bedrooms_per_usableArea                                   -0.153296
# bathrooms_per_bedrooms                                     0.131554
#
#                                      listing.suites  listing.usableAreas  \
# ALUGUEL                                    0.650935             0.699076
# listing.bathrooms                          0.809236             0.791898
# listing.bedrooms                           0.645802             0.770900
# listing.parkingSpaces                      0.614280             0.726478
# listing.pricingInfo.monthlyCondoFee        0.357453             0.301652
# listing.pricingInfo.yearlyIptu             0.243430             0.295157
# listing.suites                             1.000000             0.680169
# listing.usableAreas                        0.680169             1.000000
# bedrooms_per_usableArea                   -0.312158            -0.473113
# bathrooms_per_bedrooms                     0.410029             0.258965
#
#                                      bedrooms_per_usableArea  \
# ALUGUEL                                            -0.380266
# listing.bathrooms                                  -0.361000
# listing.bedrooms                                   -0.262338
# listing.parkingSpaces                              -0.364139
# listing.pricingInfo.monthlyCondoFee                -0.218123
# listing.pricingInfo.yearlyIptu                     -0.153296
# listing.suites                                     -0.312158
# listing.usableAreas                                -0.473113
# bedrooms_per_usableArea                             1.000000
# bathrooms_per_bedrooms                             -0.243299
#
#                                      bathrooms_per_bedrooms
# ALUGUEL                                            0.349810
# listing.bathrooms                                  0.560357
# listing.bedrooms                                  -0.030734
# listing.parkingSpaces                              0.229060
# listing.pricingInfo.monthlyCondoFee                0.233693
# listing.pricingInfo.yearlyIptu                     0.131554
# listing.suites                                     0.410029
# listing.usableAreas                                0.258965
# bedrooms_per_usableArea                           -0.243299
# bathrooms_per_bedrooms                             1.000000

# %% [markdown]
# # Preparando os dados para treinamento dos algoritmos de ML

# %%
data = train_set.drop('ALUGUEL', axis=1)
data_labels = train_set['ALUGUEL'].copy()

# %% [markdown]
# Separando duas listas com colunas numéricas e colunas categóricas

# %%
num_attribs = list(data.select_dtypes(include=[np.number]))
cat_attribs = list(data.select_dtypes(exclude=[np.number]))

# %% [markdown]
# Pipeline

# %%
# Pipeline colunas numéricas
num_pipeline = Pipeline([
    ('std_scaler', StandardScaler()),
])

# Pipeline colunas categóricas
cat_pipeline = Pipeline([
    ('one_hot', OneHotEncoder(handle_unknown='ignore'))
])

# Pipeline completa
full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', cat_pipeline, cat_attribs)
])

data_prepared = full_pipeline.fit_transform(data)

# %% [markdown]
# ### Regressão

# %%
def display_scores(scores):
    print('Scores:', scores)
    print("Média:", scores.mean())
    print("Desvio padrão:", scores.std())
    
def linear_prediction_plot(prediction, true_value):
    plt.scatter(prediction, true_value, alpha=0.2)
    plt.xlabel('Predição')
    plt.ylabel('Valor real')
    
    plt.plot([prediction.min(), true_value.max()], [prediction.min(), true_value.max()], 'k--')

# %% [markdown]
# Regressão Linear(RL)

# %%
from sklearn.model_selection import cross_val_score

lin_reg = LinearRegression()
lin_reg.fit(data_prepared, data_labels)

data_predictions = lin_reg.predict(data_prepared)
lin_mse = mean_squared_error(data_labels, data_predictions)
lin_rmse = np.sqrt(lin_mse)

lin_scores = cross_val_score(lin_reg, data_prepared, data_labels, scoring='neg_mean_squared_error', cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)

print("RMSE Lin: ", lin_rmse)
display_scores(lin_rmse_scores)

linear_prediction_plot(data_predictions, data_labels)

# R² = 1464
# Out:
# RMSE Lin:  1464.4736370763833
# Scores: [1652.54123672 1610.73726745 1662.70279416 1610.06510822 1638.44191315
#  1639.25206953 1634.70388681 1579.49643711 1545.31885796 1602.1049114 ]
# Média: 1617.5364482501325
# Desvio padrão: 33.86925824550437

# %% [markdown]
# Regressão Logisitica (RLog)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(solver='liblinear')
log_reg.fit(data_prepared, data_labels)

data_predictions = log_reg.predict(data_prepared)
log_mse = mean_squared_error(data_labels, data_predictions)
log_rmse = np.sqrt(log_mse)

print(log_rmse)

# R² = 1837
# Out:
# 1837.8486736177624

# %%
linear_prediction_plot(data_predictions, data_labels)

# %% [markdown]
# K Nearest Neighbor (KNN)

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg = KNeighborsRegressor()
knn_reg.fit(data_prepared, data_labels)

df_predictions = knn_reg.predict(data_prepared)
knn_mse = mean_squared_error(data_labels, df_predictions)
knn_rmse = np.sqrt(knn_mse)

knn_scores = cross_val_score(knn_reg, data_prepared, data_labels, scoring='neg_mean_squared_error', cv=10)
knn_rmse_scores = np.sqrt(-knn_scores)

print(knn_rmse)
display_scores(knn_rmse_scores)

linear_prediction_plot(df_predictions, data_labels)

# R² = 1187.06 - underfitting
# Out:
# 1187.7618891784307
# Scores: [1488.85989016 1484.77086854 1491.98704953 1482.82384748 1510.33380751
#  1524.94443128 1454.7994146  1461.72115387 1467.09015262 1465.51118752]
# Média: 1483.2841803109072
# Desvio padrão: 21.049896094916512

# %% [markdown]
# Decision Tree (Árvore)

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=55, max_features=11000)
tree_reg.fit(data_prepared, data_labels)

df_predictions = tree_reg.predict(data_prepared)
tree_mse = mean_squared_error(data_labels, df_predictions)
tree_rmse = np.sqrt(tree_mse)

tree_scores = cross_val_score(tree_reg, data_prepared, data_labels, scoring='neg_mean_squared_error', cv=10)
tree_rmse_scores = np.sqrt(-tree_scores)

print("RMSE Tree:", tree_rmse)
display_scores(tree_rmse_scores)

linear_prediction_plot(df_predictions, data_labels)

# R² = 30.30 = overfitting (max_depth=None)
# R² = ~500 (max_depth=32)
# R² = 260 (max_depth=40) 1m50s
# R² = 936 (max_depth=40, max_features=3000) 41s
# R² = 101 (max_depth=60) 2m13s
# R² = 148 (max_depth=50) 2m2s
# R² = 600 (max_depth=50, max_features=3000) 48s
# R² = 301 (max_depth=50, max_features=6000) 54s
# R² = 200 (max_depth=50, max_features=8000) 56s
# R² = 230 (max_depth=50, max_features=9000) 57s
# R² = 205 (max_depth=55, max_features=9000) 59s
# R² = 168 (max_depth=60, max_features=9000) 1m
# Out:
# RMSE Tree: 128.6397958325252
# Scores: [1769.34436349 1806.67760248 1803.73883019 1790.33978682 1835.01008496
#  1919.51820152 1842.2673457  1819.21206246 1770.87051213 1808.58461632]
# Média: 1816.556340606768
# Desvio padrão: 41.15664460746573

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# Com o modelo de RandomForest o score foi melhor mas ainda está overfitting

forest_reg = RandomForestRegressor(max_depth=50)
forest_reg.fit(data_prepared, data_labels)

df_predictions = forest_reg.predict(data_prepared)
forest_mse = mean_squared_error(data_labels, df_predictions)
forest_rmse = np.sqrt(forest_mse)


print(forest_rmse)

linear_prediction_plot(df_predictions, data_labels)
# Out:
# 520.4561528369833

# %% [markdown]
# ### Classificação

# %%
# Divide o padrão do imovel em categorias definidas pelo valor do aluguel (ALUGUEL MAX / 3 CATEGORIAS ≃ R$4600)
# 0 = baixo padrão
# 1 = médio padrão
# 2 = alto padrão

data_class['PADRAO'] = pd.cut(data_class['ALUGUEL'], 
                        bins=[0, 4600, 9200, np.inf],
                        labels=[0, 1, 2])

data_class = data_class.drop(['ALUGUEL'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ALUGUEL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 6
#       1 # Divide o padrão do imovel em categorias definidas pelo valor do aluguel (ALUGUEL MAX / 3 CATEGORIAS ≃ R$4600)
#       2 # 0 = baixo padrão
#       3 # 1 = médio padrão
#       4 # 2 = alto padrão
# ----> 6 data_class['PADRAO'] = pd.cut(data_class['ALUGUEL'],
#       7                         bins=[0, 4600, 9200, np.inf],
#       8                         labels=[0, 1, 2])
#      10 data_class = data_class.drop(['ALUGUEL'], axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'ALUGUEL'

# %%
# Com a coluna dividida em 3 classes é necessário utilizar o split estratificado 
# para preservar as proporções de cada classe

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in sss.split(data_class, data_class['PADRAO']):
    strat_train_set = data_class.iloc[train_index]
    strat_test_set = data_class.iloc[test_index]

# %%
train_data = strat_train_set.drop('PADRAO', axis=1)
train_data_labels = strat_train_set['PADRAO'].copy()

test_data = strat_test_set.drop('PADRAO', axis=1)
test_data_labels = strat_test_set['PADRAO'].copy()

# %%
num_attribs = list(train_data.select_dtypes(include=[np.number]))
cat_attribs = list(train_data.select_dtypes(exclude=[np.number]))

class_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', cat_pipeline, cat_attribs)
])

train_data_prepared = class_pipeline.fit_transform(train_data)
test_data_prepared = class_pipeline.transform(test_data)

# %%
from sklearn.metrics import confusion_matrix

def confusion_matrix_plot(confmat: np.ndarray):
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.4)
    for i in range(confmat.shape[0]):
        for j in range(confmat.shape[1]):
            ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')

    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=55, max_features=11000)
clf.fit(train_data_prepared, train_data_labels)

clf_predictions = clf.predict(test_data_prepared)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(test_data_labels, clf_predictions)

# accuracy_score sem ajustes = 0.8487
# Out:
# 0.8432736421488827

# %%
confmat = confusion_matrix(test_data_labels, clf_predictions)
confusion_matrix_plot(confmat)

# %% [markdown]
# KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_clf = KNeighborsClassifier(n_neighbors=6)
knn_clf.fit(train_data_prepared, train_data_labels)

knn_clf_predictions = knn_clf.predict(test_data_prepared)

# %%
accuracy_score(test_data_labels, knn_clf_predictions)
# Out:
# 0.8590350747373094

# %%
confmat = confusion_matrix(test_data_labels, knn_clf_predictions)
confusion_matrix_plot(confmat)

# %% [markdown]
# AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_clf = AdaBoostClassifier(n_estimators=400)
ada_clf.fit(train_data_prepared, train_data_labels)

ada_clf_predictions = ada_clf.predict(test_data_prepared)

# %%
accuracy_score(test_data_labels, ada_clf_predictions)
# Out:
# 0.8462335355927186

# %%
confmat = confusion_matrix(test_data_labels, ada_clf_predictions)
confusion_matrix_plot(confmat)

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier()
rf_clf.fit(train_data_prepared, train_data_labels)

rf_clf_predictions = rf_clf.predict(test_data_prepared)

# %%
accuracy_score(test_data_labels, rf_clf_predictions)
# Out:
# 0.8796803315080657

# %%
confmat = confusion_matrix(test_data_labels, rf_clf_predictions)
confusion_matrix_plot(confmat)
